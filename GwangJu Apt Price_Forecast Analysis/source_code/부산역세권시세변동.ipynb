# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from fbprophet import Prophet
from datetime import datetime
plt.rcParams['figure.figsize']=(20,10)
plt.style.use('ggplot')

# %%
path = "c:/Windows/Fonts/malgun.ttf"
import platform
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')    

plt.rcParams['axes.unicode_minus'] = False

# %%
pop = pd.read_excel('../data/부산역세권데이터 년도.xlsx',  encoding='euc-kr')
pop.head()
# Out:
#                          시군구  20080317  20080828  20100611  20100916  \
# 0  부산광역시 동래구 수안동 엘리유리안 84.33     15700     16500     23500     22000
#
#    20110206  20111109
# 0     23750     28100

# %%
pop1=pop.loc[(pop["시군구"]=="부산광역시 동래구 수안동 엘리유리안 84.33"),["시군구"]]

# %%
pop1 = pop.plot(kind='bar', title='시세변동',figsize=(12,6), legend=True, fontsize=12)
pop1.set_xlabel('부산광역시 동래구 수안동 엘리유리안 84.33', fontsize=12)
pop1.set_ylabel('시세',fontsize=12)
# Out:
# Text(0, 0.5, '시세')

# %%
pop2 = pd.read_excel('../data/부산.xlsx',  encoding='euc-kr')
pop.head()
# Out:
#                                시군구  20080923  20090810  20100430  20110917  \
# 0  광주광역시 남구 봉선동 한국아델리움2단지 129.6596     28660     36000     38000     37000
#
#    20111029  20120910  20130811  20140731  20150223  20150928  20161219  \
# 0     42000     44500     46000     48500     47800     57700     72000
#
#    20170222  20171110
# 0     78000     89900

# %%
pop3=pop2.loc[(pop["시군구"]=="부산광역시 동래구 낙민동 한신1 73.89"),["시군구"]]

# %%
pop3 = pop2.plot(kind='bar', title='시세변동',figsize=(12,6), legend=True, fontsize=12)
pop3.set_xlabel('부산광역시 동래구 낙민동 한신1 73.89', fontsize=12)
pop3.set_ylabel('시세',fontsize=12)
# Out:
# Text(0, 0.5, '시세')

# %%
pop4 = pd.read_excel('../data/부산.xlsx',  encoding='euc-kr')
pop4.head()
# Out:
#                                시군구  20080923  20090810  20100430  20110917  \
# 0  광주광역시 남구 봉선동 한국아델리움2단지 129.6596     28660     36000     38000     37000
#
#    20111029  20120910  20130811  20140731  20150223  20150928  20161219  \
# 0     42000     44500     46000     48500     47800     57700     72000
#
#    20170222  20171110
# 0     78000     89900

# %%
pop5=pop4.loc[(pop["시군구"]=="광주광역시 남구 봉선동 한국아델리움2단지 129.6596"),["시군구"]]

# %%
pop5 = pop4.plot(kind='bar', title='시세변동',figsize=(12,6), legend=True, fontsize=12)
pop5.set_xlabel('광주광역시 남구 봉선동 한국아델리움2단지 129.6596', fontsize=12)
pop5.set_ylabel('시세',fontsize=12)
# Out:
# Text(0, 0.5, '시세')

# %%
pop6 = pd.read_excel('../data/부산.xlsx',  encoding='euc-kr')
pop6.head()
# Out:
#                               시군구  20090921  20100323  20100614  20110721  \
# 0  광주광역시 광산구 수완동 대주피오레6단지 84.8453     16300     17700     21500     24000
#
#    20130619  20140623  20150912  20160922  20170612  20170810  20170915  \
# 0     23800     32700     34800     40000     42500     30800     34700
#
#    20171110  20180315  20180415  20180426  20180821  20180914  20181024  \
# 0     35500     42000     52000     46200     48500     49400     53300
#
#    20190226
# 0     48000

# %%
pop7=pop6.loc[(pop["시군구"]=="광주광역시 광산구 수완동 대주피오레6단지 84.8453"),["시군구"]]

# %%
pop7 = pop6.plot(kind='bar', title='시세변동',figsize=(12,6), legend=True, fontsize=12)
pop7.set_xlabel('광주광역시 광산구 수완동 대주피오레6단지 84.8453', fontsize=12)
pop7.set_ylabel('시세',fontsize=12)
# Out:
# Text(0, 0.5, '시세')
